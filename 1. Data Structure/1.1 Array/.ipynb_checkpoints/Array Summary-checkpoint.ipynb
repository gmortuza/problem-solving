# %% [markdown]
# <h3>Array Vs List</h3>
# <style>
#     .rendered_html tr, .rendered_html th, .rendered_html td{
#         text-align: center!important;
#         width: 50%;
#         border:1px solid black!important;
#     }
# </style>
# <table style="width:100%; text-align:center;">
#     <thead>
#         <tr>
#             <td style="width:100%; text-align:center;"><strong>List</strong></td>
#             <td style="width:100%; text-align:center;"><strong>Array</strong></td>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>More memory than array</td>
#             <td>Less memory than List</td>
#         </tr>
#         <tr>
#             <td>Slower</td>
#             <td>Faster</td>
#         </tr>
#         <tr>
#             <td>Homogeneous</td>
#             <td>Heterogeneous</td>
#         </tr>
#         <tr>
#             <td>Flexible</td>
#             <td>Not Flexiable like list</td>
#         </tr>
#         <tr>
#             <td>Don't need to be imported</td>
#             <td>Not Flexiable like list</td>
#         </tr>
#         <tr>
#             <td>initialized by []</td>
#             <td>initialized by array(typecode[, initializer])</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# <h3>Array complexiteis</h3>
# <style>
#     .rendered_html tr, .rendered_html th, .rendered_html td{
#         text-align: center!important;
#         width: 50%;
#         border:1px solid black!important;
#     }
# </style>
# <table style="width:100%; text-align:center;">
#   <tr>
#     <th></th>
#     <th style="width:100%; text-align:center;">Best</th>
#     <th style="width:100%; text-align:center;">Average</th>
#     <th style="width:100%; text-align:center;">Worst</th>
#   </tr>
#   <tr>
#     <td>Insert</td>
#     <td>O(1)</td>
#     <td>O(n)</td>
#     <td>O(n)</td>
#   </tr>
#   <tr>
#     <td>delete</td>
#     <td>O(1)</td>
#     <td>O(n)</td>
#     <td>O(n)</td>
#   </tr>
#   <tr>
#     <td>Search</td>
#     <td>O(1)</td>
#     <td>O(n)</td>
#     <td>O(n)</td>
#   </tr>
#   <tr>
#     <td>Access</td>
#     <td>O(1)</td>
#     <td>O(1)</td>
#     <td>O(1)</td>
#   </tr>
# </table>
